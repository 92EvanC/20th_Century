# %%
import spacy
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load text file
file_path = "cleaned_20th_century_text.txt"

try:
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()
    print("File loaded successfully! Preview:\n")
    print(text[:500])  # Show first 500 characters as a preview
except FileNotFoundError:
    print("Error: File not found. Please check the file path.")
# Out:
# File loaded successfully! Preview:
#
#
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Learn to edit
# Community portal
# Recent changes
# Special pages
# Donate
# Create account
#  Create account
#
# Contributions
# Top
# Summary
# Nature of innovation and change
# Social change
# Earth at the end of the 20th century
# Wars and politics
# Culture and entertainment
# Toggle Culture and entertainment subsection
# .
# Music
# Film, television and theatre
# Video games
# Art and architecture
# Sport
# Science
# Toggle Science subsection
# Mathematics
# Physics
# Astron

# %%
import re
special_chars = re.findall(r"[^a-zA-Z0-9.,;!?'\s]", text)
print(f"Special characters found: {set(special_chars)}")  # Unique special characters
# Out:
# Special characters found: {'Л', 'Ч', 'າ', 'ế', '-', 'Æ', 'ц', 'ള', 'Б', 'ç', 'ى', 'ø', 'Н', 'î', 'ե', 'ழ', 'ਜ', 'õ', 'ລ', 'Т', 'හ', 'ת', 'ማ', 'ə', 'ص', 'ج', 'म', '閩', 'မ', 'უ', 'з', '어', 'م', 'Հ', 'ह', 'á', '语', 'Р', 'ښ', 'ქ', 'О', 'Ε', '客', 'യ', 'ҷ', 'ó', 'ն', 'я', 'ம', 'த', 'Ӏ', 'у', 'ń', 'മ', 'ʻ', 'с', 'د', 'ल', 'х', 'သ', 'é', 'ب', 'ة', 'ր', 'త', 'ဘ', 'ї', 'र', 'ъ', '文', 'Г', 'ల', 'ў', 'Ž', 'ਬ', 'प', 'ۆ', 'М', 'ש', 'ن', 'ل', 'ي', 'ì', 'न', 'አ', 'గ', 'д', 'द', '中', 'յ', 'ল', 'س', '東', '南', 'ר', 'г', 'č', 'ӣ', 'è', 'ă', 'і', 'ד', 'à', 'ů', 'ά', '吴', 'ز', 'ш', 'و', 'ı', 'š', 'и', 'ê', 'л', 'ی', 'С', 'а', 'ლ', 'ر', 'У', 'â', 'ت', 'ι', '粵', '本', 'т', 'ठ', 'ه', 'ኛ', 'й', 'ñ', 'ย', 'ი', 'ท', 'რ', 'ā', 'ӑ', 'მ', 'ල', '贛', 'ҡ', 'К', 'Ś', '국', 'ա', 'ν', 'н', 'ĕ', 'ş', 'ė', 'န', 'ല', 'б', 'ë', 'ไ', 'о', 'Э', 'ü', 'پ', 'е', 'Í', 'И', 'ວ', 'ف', '語', 'å', 'р', 'ב', 'ა', '한', 'ע', 'ļ', '日', 'ч', 'к', 'ṳ', 'қ', 'ၽ', 'ú', 'λ', 'თ', 'Қ', 'ò', '家', 'κ', 'י', 'м', 'в', 'ا', 'ų', 'တ', 'ь', 'ਪ', 'ব', 'გ', 'А', 'ස', 'п', 'Č', 'η', 'ር', 'ы', 'ệ', 'ک', 'ع'}

# %%
# Remove special characters (except common punctuation)
cleaned_text = re.sub(r"[^a-zA-Z0-9.,;!?'\s]", "", text)

# %%
# Normalize whitespace
cleaned_text = re.sub(r"\s+", " ", cleaned_text).strip()

# %%
# Save cleaned text
with open("cleaned_text.txt", "w", encoding="utf-8") as file:
    file.write(cleaned_text)

# %%
print("\nCleaned text preview:\n", cleaned_text[:500])
# Out:
# Cleaned text preview:
#  Contents Current events Random article About Wikipedia Contact us Learn to edit Community portal Recent changes Special pages Donate Create account Create account Contributions Top Summary Nature of innovation and change Social change Earth at the end of the 20th century Wars and politics Culture and entertainment Toggle Culture and entertainment subsection . Music Film, television and theatre Video games Art and architecture Sport Science Toggle Science subsection Mathematics Physics Astronomy

# %%
# Load spacy English model
nlp = spacy.load("en_core_web_sm")

# %%
# Create an NLP document
doc = nlp(cleaned_text)

# %%
# Display named entities 
for ent in doc.ents[:10]:  # Show first 10 entities
    print(f"{ent.text} - {ent.label_}")
# Out:
# Community - ORG
# Earth - LOC
# the end of the 20th century - DATE
# Toggle Culture - ORG
# Sport Science Toggle Science subsection Mathematics Physics Astronomy Agriculture Biology Medicine - ORG
# Energy - ORG
# Engineering - PERSON
# Toggle Engineering - ORG
# External - ORG
# Afrikaans - NORP

# %%
# Extract all sentences from the document
sentences = list(doc.sents)

# %%
# Loop through all sentences and display their named entities
for sent in sentences:
    print(f"\nSentence: {sent.text}")  # Print the sentence
    for ent in sent.ents:
        print(f" - Entity: {ent.text} ({ent.label_})")  # Print each entity found
# Out:
# Sentence: Contents Current events Random article About Wikipedia Contact us Learn to edit Community portal Recent changes Special pages Donate Create account Create account Contributions
#  - Entity: Community (ORG)
#
# Sentence: Top Summary Nature of innovation and change Social change Earth at the end of the 20th century Wars and politics Culture and entertainment Toggle Culture and entertainment subsection .
#  - Entity: Earth (LOC)
#  - Entity: the end of the 20th century (DATE)
#  - Entity: Toggle Culture (ORG)
#
# Sentence: Music Film, television and theatre Video games Art and architecture Sport Science Toggle Science subsection Mathematics Physics Astronomy Agriculture Biology Medicine .. Notable diseases Energy and the environment Engineering and technology Toggle Engineering and technology subsection Space exploration Religion Economics See also References Sources Further reading External links Afrikaans Alemannisch nglisc Aragons Arpetan Asturianu Azrbaycanca Basa Bali Bnlmg Basa Banyumasan Bosanski Brezhoneg Catal Cebuano etina Cymraeg Dansk Davvismegiella Deutsch Eesti Emilin e rumagnl Espaol Esperanto Estremeu
#  - Entity: Sport Science Toggle Science subsection Mathematics Physics Astronomy Agriculture Biology Medicine (ORG)
#  - Entity: Energy (ORG)
#  - Entity: Engineering (PERSON)
#  - Entity: Toggle Engineering (ORG)
#  - Entity: External (ORG)
#  - Entity: Afrikaans (NORP)
#  - Entity: Aragons Arpetan Asturianu (ORG)
#  - Entity: Cymraeg Dansk Davvismegiella (PERSON)
#  - Entity: Emilin (GPE)
#  - Entity: Espaol (ORG)
#
# Sentence: Euskara Fiji Hindi Froyskt Franais Frysk Gaeilge Gaelg Gidhlig Galego Hakkng Hornjoserbsce Hrvatski Ido Ilokano Bahasa Indonesia Interlingua slenska Italiano Jawa Kernowek Kiswahili Kotava Kurd Latgau Latina Latvieu Ltzebuergesch Lietuvi
#  - Entity: Euskara Fiji (PERSON)
#  - Entity: Hindi Froyskt (PERSON)
#  - Entity: Hornjoserbsce Hrvatski Ido Ilokano (PERSON)
#  - Entity: Bahasa (GPE)
#  - Entity: Indonesia (GPE)
#  - Entity: slenska (GPE)
#  - Entity: Kernowek Kiswahili (PERSON)
#  - Entity: Kurd Latgau (PERSON)
#  - Entity: Latina Latvieu Ltzebuergesch (PERSON)
#
# Sentence: Ligure Limburgs Lingla Lingua Franca Nova Livvinkarjala La .lojban.
#  - Entity: Livvinkarjala La .lojban (PERSON)
#
# Sentence: Lombard Magyar Mori Bahasa Melayu Minangkabau Mngdngng Mirands Nhuatl Nederlands Nedersaksies Napulitano Nordfriisk Norsk bokml Norsk nynorsk
#  - Entity: Magyar Mori Bahasa (PERSON)
#  - Entity: Norsk (PRODUCT)
#
# Sentence: Nouormand Novial Occitan Ozbekcha Papiamentu Plattdtsch Polski Portugus Romn Rumantsch Runa Simi Scots Seeltersk Sesotho sa Leboa Shqip Sicilianu Simple English Slovenina Slovenina lnski Soomaaliga srpski Srpskohrvatski Sunda Suomi Svenska Tagalog Taqbaylit tatara Trke Trkmene Vneto Ting Vit Volapk
#  - Entity: Nouormand Novial Occitan Ozbekcha Papiamentu Plattdtsch Polski Portugus Romn Rumantsch Runa (ORG)
#  - Entity: Seeltersk Sesotho (PERSON)
#  - Entity: English (NORP)
#  - Entity: Soomaaliga (GPE)
#  - Entity: Srpskohrvatski Sunda (ORG)
#  - Entity: Suomi (GPE)
#  - Entity: Svenska (GPE)
#  - Entity: Tagalog (LANGUAGE)
#  - Entity: Vneto Ting Vit Volapk (PERSON)
#
# Sentence: Vro Walon Winaray Zazaki Zeuws emaitka Toli Article Read Edit View history
#  - Entity: Zazaki Zeuws (PERSON)
#
# Sentence: What links here Related changes Permanent link Page information Cite this page Get shortened URL Download QR code Edit interlanguage links Expand all Download as PDF Printable version Wikimedia Commons Wikiquote Wikidata item SmallStandardLarge StandardWide AutomaticLightDark 19th century 20th century 21st century 1900s 1910s 1920s 1930s 1940s 1950s 1960s 1970s 1980s 1990s v t e RussoJapanese War, between the Russian Empire and the Empire of Japan during and over rival imperial ambitions in Manchuria and the Korean Empire.
#  - Entity: Download QR (WORK_OF_ART)
#  - Entity: Expand (GPE)
#  - Entity: Download (GPE)
#  - Entity: PDF Printable (ORG)
#  - Entity: Wikimedia Commons (ORG)
#  - Entity: 19th century 20th century 21st century (DATE)
#  - Entity: 1930s 1940s 1950s 1960s (DATE)
#  - Entity: 1980s 1990s (DATE)
#  - Entity: RussoJapanese War (EVENT)
#  - Entity: the Russian Empire (GPE)
#  - Entity: the Empire of Japan (GPE)
#  - Entity: Manchuria (GPE)
#  - Entity: the Korean Empire (GPE)
#
# Sentence: Russian Revolution of , a wave of mass political and social unrest then began to spread across the vast areas of the Russian Empire.
#  - Entity: the Russian Empire (GPE)
#
# Sentence: The unrest was directed primarily against the Tsar, the nobility, and the ruling class.
#  - Entity: Tsar (GPE)
#
# Sentence: It included worker strikes, peasant unrest, and military mutinies.
#
# Sentence: Sinking of the Titanic, RMS Titanic sank on April in the North Atlantic Ocean.
#  - Entity: April (DATE)
#  - Entity: the North Atlantic Ocean (LOC)
#
# Sentence: The largest ocean liner in service at the time, Titanic was four days into her maiden voyage from Southampton, England, to New York City, with an estimated , people on board when she struck an iceberg at ships timea on April.
#  - Entity: Titanic (ORG)
#  - Entity: four days (DATE)
#  - Entity: Southampton (GPE)
#  - Entity: England (GPE)
#  - Entity: New York City (GPE)
#  - Entity: April (DATE)
#
# Sentence: The Armenian, Assyrian and Greek genocide were the systematic destruction, mass murder and expulsion of the Armenians, Assyrians and Greeks in the Ottoman Empire during World War I, spearheaded by the ruling Committee of Union and Progress CUP.
#  - Entity: Armenian (NORP)
#  - Entity: Assyrian (NORP)
#  - Entity: Greek (NORP)
#  - Entity: Armenians (NORP)
#  - Entity: Assyrians (NORP)
#  - Entity: Greeks (PERSON)
#  - Entity: the Ottoman Empire (GPE)
#  - Entity: World War I (EVENT)
#  - Entity: Committee of Union and Progress CUP (ORG)
#
# Sentence: The Alliance of Eight Nations AustroHungarian Empire, French Republic, German Empire, Kingdom of Italy, Empire of Japan, Russian Empire, United Kingdom of Great Britain and Ireland and United States of America formed in to invade the Qing China represented the club of great powers in the early 20th century.
#  - Entity: The Alliance of Eight Nations (ORG)
#  - Entity: French Republic (GPE)
#  - Entity: German Empire (GPE)
#  - Entity: Kingdom of Italy (GPE)
#  - Entity: Empire (GPE)
#  - Entity: Japan (GPE)
#  - Entity: Russian Empire (GPE)
#  - Entity: United Kingdom of (GPE)
#  - Entity: Great Britain (GPE)
#  - Entity: Ireland (GPE)
#  - Entity: United States of America (GPE)
#  - Entity: Qing (DATE)
#  - Entity: China (GPE)
#  - Entity: the early 20th century (DATE)
#
# Sentence: Rising nationalism and increasing national awareness were among the many causes of World War I , the first of two wars to involve many major world powers including Germany, France, Italy, Japan, RussiaUSSR, the British Empire and the United States.
#  - Entity: World War I (EVENT)
#  - Entity: first (ORDINAL)
#  - Entity: two (CARDINAL)
#  - Entity: Germany (GPE)
#  - Entity: France (GPE)
#  - Entity: Italy (GPE)
#  - Entity: Japan (GPE)
#  - Entity: RussiaUSSR (GPE)
#  - Entity: the British Empire (GPE)
#  - Entity: the United States (GPE)
#
# Sentence: At the time, it was said by many to be the war to end all wars.
#
# Sentence: The Arab Revolt of was an armed uprising against the Ottoman Empire done by the Arabs in agreement with the British Empire.
#  - Entity: The Arab Revolt (ORG)
#  - Entity: Ottoman Empire (GPE)
#  - Entity: Arabs (NORP)
#  - Entity: the British Empire (GPE)
#
# Sentence: The revolt was led by Sharif Hussein bin Ali who was promised by Henry McMahon, the British High Commissioner in Egypt, that in exchange for fighting the Ottoman Empire, Sharif Hussein would gain control over all Arab lands under the Ottoman Empire.
#  - Entity: Sharif Hussein bin Ali (PERSON)
#  - Entity: Henry McMahon (PERSON)
#  - Entity: British (NORP)
#  - Entity: Egypt (GPE)
#  - Entity: the Ottoman Empire (GPE)
#  - Entity: Sharif Hussein (PERSON)
#  - Entity: Arab (NORP)
#  - Entity: the Ottoman Empire (GPE)
#
# Sentence: A promise the British Empire did not honor.
#  - Entity: the British Empire (GPE)
#
# Sentence: During World War I, in the Russian Revolution of , years of Tsarist reign were ended and the Bolsheviks, under the leadership of Vladimir Lenin, established the worlds first Communist state.
#  - Entity: World War I (EVENT)
#  - Entity: the Russian Revolution of , years (EVENT)
#  - Entity: Tsarist (NORP)
#  - Entity: Bolsheviks (GPE)
#  - Entity: Vladimir Lenin (PERSON)
#  - Entity: first (ORDINAL)
#  - Entity: Communist (NORP)
#
# Sentence: The end of World War I saw the collapse of the central powers, the German Empire, the AustrianHungarian Empire, the Kingdom of Bulgaria, and the Ottoman Empire into several independent sovereign states throughout Central Europe, the Balkans, and the Middle East.
#  - Entity: World War I (EVENT)
#  - Entity: the German Empire (GPE)
#  - Entity: the AustrianHungarian Empire (GPE)
#  - Entity: the Kingdom of Bulgaria (GPE)
#  - Entity: the Ottoman Empire (GPE)
#  - Entity: Central Europe (LOC)
#  - Entity: Balkans (LOC)
#  - Entity: the Middle East (LOC)
#
# Sentence: After gaining political rights in the United States and much of Europe in the first part of the century, and with the advent of new birth control techniques, women became more independent throughout the century.
#  - Entity: the United States (GPE)
#  - Entity: Europe (LOC)
#  - Entity: first (ORDINAL)
#  - Entity: the century (DATE)
#  - Entity: the century (DATE)
#
# Sentence: Industrial warfare greatly increased in its scale and complexity during the first half of the 20th century.
#  - Entity: the first half of the 20th century (DATE)
#
# Sentence: Notable developments included chemical warfare, the introduction of military aviation and the widespread use of submarines.
#
# Sentence: The introduction of nuclear warfare in the mid20th century marked the definite transition to modern warfare.
#  - Entity: the mid20th century (DATE)
#
# Sentence: The Revolutions of occurred during and World War I inspired by the Russian Revolution which saw many political changes in Europe and in Asia.
#  - Entity: World War (EVENT)
#  - Entity: the Russian Revolution (EVENT)
#  - Entity: Europe (LOC)
#  - Entity: Asia (LOC)
#
# Sentence: The Osage Murders of were a series of killings of members of the Native American Osage Nation, who were the richest people per capita in the world at that time.
#  - Entity: the Native American Osage Nation (ORG)
#
# Sentence: The Tulsa Race Massacre, was a racist anti black terrorist attack in the Greenwood District in Tulsa, Oklahoma, which was home to many successful and wealthy Black Americans.
#  - Entity: The Tulsa Race Massacre (ORG)
#  - Entity: the Greenwood District (LOC)
#  - Entity: Tulsa (GPE)
#  - Entity: Oklahoma (GPE)
#  - Entity: Black Americans (NORP)
#
# Sentence: The attack was perpetrated by white residents and local white deputies.
#
# Sentence: The perpetrators were armed by local government officials.
#
# Sentence: The Beer Hall Putsch failed coup dtat by Nazi Party leader Adolf Hitler.
#  - Entity: The Beer Hall Putsch (ORG)
#  - Entity: Nazi Party (ORG)
#  - Entity: Adolf Hitler (PERSON)
#
# Sentence: The Great Depression in the 1930s led to the rise of Fascism especially Nazism in Europe.
#  - Entity: The Great Depression (EVENT)
#  - Entity: the 1930s (DATE)
#  - Entity: Fascism (NORP)
#  - Entity: Europe (LOC)
#
# Sentence: Holodomor, manmade famine in Soviet Ukraine from to that killed millions of Ukrainians.
#  - Entity: Soviet (NORP)
#  - Entity: Ukraine (GPE)
#  - Entity: millions (CARDINAL)
#  - Entity: Ukrainians (NORP)
#
# Sentence: Night of the Long Knives, purge that took place in Nazi Germany from June to July .
#  - Entity: Nazi Germany (GPE)
#  - Entity: June to July (DATE)
#
# Sentence: The to Long March, military retreat by the Chinese Red Army and Chinese Communist Party CCP from advancing Kuomintang forces.
#  - Entity: The to Long March (DATE)
#  - Entity: the Chinese Red Army (ORG)
#  - Entity: Chinese Communist Party CCP (ORG)
#  - Entity: Kuomintang (ORG)
#
# Sentence: A violent civil war broke out in Spain in when General Francisco Franco rebelled against the Second Spanish Republic.
#  - Entity: Spain (GPE)
#  - Entity: Francisco Franco (PERSON)
#  - Entity: Second (ORDINAL)
#
# Sentence: Many consider this war as a testing battleground for World War II, as the fascist armies bombed some Spanish territories.
#  - Entity: World War II (EVENT)
#  - Entity: Spanish (NORP)
#
# Sentence: Great Purge, political purge in the Soviet Union that took place from and .
#  - Entity: Great Purge (FAC)
#  - Entity: the Soviet Union (GPE)
#
# Sentence: The Kristallnacht, pogrom against Jews carried out by the Nazi Partys Sturmabteilung SA and Schutzstaffel SS paramilitary forces World War II became the deadliest conflict in human history involving primarily the axis, Nazi Germany, Fascist Italy, and the Empire of Japan against the allies, China, France, the United Kingdom, the Soviet Union, and the United States.
#  - Entity: Kristallnacht (PERSON)
#  - Entity: Jews (NORP)
#  - Entity: the Nazi Partys Sturmabteilung SA (ORG)
#  - Entity: World War II (EVENT)
#  - Entity: Nazi Germany (GPE)
#  - Entity: Fascist Italy (PERSON)
#  - Entity: the Empire of Japan (GPE)
#  - Entity: China (GPE)
#  - Entity: France (GPE)
#  - Entity: the United Kingdom (GPE)
#  - Entity: the Soviet Union (GPE)
#  - Entity: the United States (GPE)
#
# Sentence: Many atrocities occurred, particularly the Holocaust killing approximately million victims.
#  - Entity: Holocaust (FAC)
#  - Entity: approximately million (CARDINAL)
#
# Sentence: It ended with the atomic bombings on Hiroshima and Nagasaki in Japan.
#  - Entity: Hiroshima (GPE)
#  - Entity: Nagasaki (GPE)
#  - Entity: Japan (GPE)
#
# Sentence: The two world wars led to efforts to increase international cooperation, notably through the founding of the League of Nations after World War I, and its successor, the United Nations, after World War II.
#  - Entity: two (CARDINAL)
#  - Entity: the League of Nations after (ORG)
#  - Entity: World War I (EVENT)
#  - Entity: the United Nations (ORG)
#  - Entity: World War II (EVENT)
#
# Sentence: The creation of Israel in , a Jewish state in the Middle East, at the end of the British Mandate for Palestine, fueled many conflicts between Israelis and Palestinians in addition to regional conflicts.
#  - Entity: Israel (GPE)
#  - Entity: Jewish (NORP)
#  - Entity: the Middle East (LOC)
#  - Entity: the British Mandate for Palestine (ORG)
#  - Entity: Israelis (NORP)
#  - Entity: Palestinians (NORP)
#
# Sentence: These were also influenced by the vast oil fields in many of the other countries of the predominantly Arab region.
#  - Entity: Arab (NORP)
#
# Sentence: In The Nakba was, according to several historians, a targeted ethnic cleansing campaign against Arabs in Palestine perpetrated by Jewish Militias under Plan Delta, a plan ordered by BenGurion.
#  - Entity: Nakba (PERSON)
#  - Entity: Arabs (NORP)
#  - Entity: Palestine (GPE)
#  - Entity: Jewish Militias (ORG)
#  - Entity: BenGurion (ORG)
#
# Sentence: The campaign utilized methods of intimidation, violent attacks, and the destruction of several Arab villages.
#  - Entity: Arab (NORP)
#
# Sentence: After the Soviet Unions involvement in World War II, communism became a major force in global politics, notably in Eastern Europe, China, Indochina and Cuba, where communist parties gained nearabsolute power.
#  - Entity: Soviet Unions (GPE)
#  - Entity: World War II (EVENT)
#  - Entity: Eastern Europe (LOC)
#  - Entity: China (GPE)
#  - Entity: Indochina (GPE)
#  - Entity: Cuba (GPE)
#  - Entity: communist (NORP)
#
# Sentence: The Cold War involved an arms race and increasing competition between the two major players in the world the Soviet Union and the United States.
#  - Entity: The Cold War (EVENT)
#  - Entity: two (CARDINAL)
#  - Entity: the Soviet Union (GPE)
#  - Entity: the United States (GPE)
#
# Sentence: This competition included the development and improvement of nuclear weapons and space technology.
#
# Sentence: This led to the proxy wars with the Western bloc, including wars in Korea and Vietnam .
#  - Entity: Western (NORP)
#  - Entity: Korea (GPE)
#  - Entity: Vietnam (GPE)
#
# Sentence: The Soviet authorities caused the deaths of millions of their own citizens to eliminate domestic opposition.
#  - Entity: Soviet (NORP)
#  - Entity: millions (CARDINAL)
#
# Sentence: More than million people passed through the Gulag, with a further million being exiled to remote areas of the Soviet Union.
#  - Entity: More than million (CARDINAL)
#  - Entity: Gulag (ORG)
#  - Entity: million (CARDINAL)
#  - Entity: the Soviet Union (GPE)
#
# Sentence: Nationalist movements in the Indian subcontinent led to the independence and partition of Jawaharlal
#  - Entity: Indian (NORP)
#  - Entity: Jawaharlal (GPE)
#
# Sentence: Nehruled India and Muhammad Ali Jinnahled Pakistan, although would lead to conflicts between the two nations such as border and territorial disputes.
#  - Entity: India (GPE)
#  - Entity: Muhammad Ali (PERSON)
#  - Entity: Pakistan (GPE)
#  - Entity: two (CARDINAL)
#
# Sentence: After a long period of civil wars and conflicts with western powers, Chinas last imperial dynasty ended in .
#  - Entity: Chinas (ORG)
#  - Entity: last imperial dynasty ended in (DATE)
#
# Sentence: The resulting republic was replaced, after another civil war, by the communist Peoples Republic of China in .
#  - Entity: Peoples Republic of China (GPE)
#
# Sentence: At the end of the 20th century, though still ruled by a communist party, Chinas economic system had largely transformed to capitalism.
#  - Entity: the end of the 20th century (DATE)
#  - Entity: a communist party (ORG)
#  - Entity: Chinas (ORG)
#
# Sentence: Mahatma Gandhis nonviolence and Indian independence movement against the British Empire influenced many political movements around the world, including the civil rights movement in the United States, and freedom movements in South Africa against apartheid challenging racial segregation The end of colonialism led to the independence of many African and Asian countries.
#  - Entity: Mahatma (PERSON)
#  - Entity: Indian (NORP)
#  - Entity: the British Empire (ORG)
#  - Entity: the United States (GPE)
#  - Entity: South Africa (GPE)
#  - Entity: African (NORP)
#  - Entity: Asian (NORP)
#
# Sentence: During the Cold War, many of these aligned with the United States, the USSR, or China for defense.
#  - Entity: the Cold War (EVENT)
#  - Entity: the United States (GPE)
#  - Entity: USSR (GPE)
#  - Entity: China (GPE)
#
# Sentence: Pozna protests, the first of several massive protests against the communist government of the Polish Peoples Republic.
#  - Entity: first (ORDINAL)
#  - Entity: the Polish Peoples Republic (GPE)
#
# Sentence: Hungarian Revolution of , attempted countrywide revolution against the government of the Hungarian Peoples Republic and the policies caused by the governments subordination to the Soviet Union USSR.
#  - Entity: the Hungarian Peoples Republic (GPE)
#  - Entity: the Soviet Union (GPE)
#  - Entity: USSR (GPE)
#
# Sentence: Mao Zedongs radical policy of modernization leads to the Great Chinese Famine causing the death of tens of millions of Chinese peasants between and .
#  - Entity: Mao Zedongs (PERSON)
#  - Entity: the Great Chinese Famine (EVENT)
#  - Entity: tens of millions (MONEY)
#  - Entity: Chinese (NORP)
#
# Sentence: It is thought to be the largest famine in human history.
#
# Sentence: Cuban Missile Crisis, day confrontation between the governments of the United States and the Soviet Union, when American deployments of nuclear missiles in Italy and Turkey were matched by Soviet deployments of nuclear missiles in Cuba.
#  - Entity: Cuban Missile Crisis (ORG)
#  - Entity: the United States (GPE)
#  - Entity: the Soviet Union (GPE)
#  - Entity: American (NORP)
#  - Entity: Italy (GPE)
#  - Entity: Turkey (GPE)
#  - Entity: Soviet (NORP)
#  - Entity: Cuba (GPE)
#
# Sentence: The Vietnam War caused two million deaths, changed the dynamics between the Eastern and Western Blocs, and altered global NorthSouth relations.
#  - Entity: The Vietnam War (EVENT)
#  - Entity: two million (CARDINAL)
#  - Entity: Eastern (ORG)
#  - Entity: Western Blocs (LOC)
#  - Entity: NorthSouth (ORG)
#
# Sentence: The SixDay War, fought between Israel and a coalition of Arab states, primarily Egypt, Syria, and Jordan.
#  - Entity: The SixDay War (EVENT)
#  - Entity: Israel (GPE)
#  - Entity: Arab (NORP)
#  - Entity: Egypt (GPE)
#  - Entity: Syria (GPE)
#  - Entity: Jordan (GPE)
#
# Sentence: The Prague Spring, period of political liberalization and mass protest in the Czechoslovak Socialist Republic.
#  - Entity: the Czechoslovak Socialist Republic (ORG)
#
# Sentence: Polish protests, protests were sparked by a sudden increase in the prices of food and other everyday items while wages remained stagnant.
#  - Entity: Polish (NORP)
#
# Sentence: Yom Kippur War, fought from to October between Israel and a coalition of Arab states led by Egypt and Syria.
#  - Entity: Yom Kippur War (PERSON)
#  - Entity: October (DATE)
#  - Entity: Israel (GPE)
#  - Entity: Arab (NORP)
#  - Entity: Egypt (GPE)
#  - Entity: Syria (GPE)
#
# Sentence: Iranian revolution, series of events that culminated in the overthrow of the Pahlavi dynasty in .
#  - Entity: Iranian (NORP)
#  - Entity: the Pahlavi dynasty (EVENT)
#
# Sentence: The Soviet invasion of Afghanistan caused an estimated two million deaths and contributed to the dissolution of the Soviet Union along with complete political turmoil in Afghanistan36
#  - Entity: Soviet (NORP)
#  - Entity: Afghanistan (GPE)
#  - Entity: an estimated two million (CARDINAL)
#  - Entity: the Soviet Union (GPE)
#
# Sentence: The Martial law in Poland, The government of the Polish Peoples Republic drastically restricted everyday life by introducing martial law and a military junta in an attempt to counter political opposition, in particular the Solidarity movement.
#  - Entity: Poland (GPE)
#  - Entity: the Polish Peoples Republic (GPE)
#  - Entity: Solidarity (ORG)
#
# Sentence: The Chernobyl disaster, worst nuclear disaster in history.
#  - Entity: Chernobyl (GPE)
#
# Sentence: Some Ukrainians viewed the Chernobyl disaster as another attempt by Russians to destroy them, comparable to the Holodomor.
#  - Entity: Ukrainians (NORP)
#  - Entity: Chernobyl (GPE)
#  - Entity: Russians (NORP)
#
# Sentence: The revolutions of released Eastern and Central Europe from Soviet control.
#  - Entity: Eastern (ORG)
#  - Entity: Central Europe (LOC)
#  - Entity: Soviet (NORP)
#
# Sentence: Soon thereafter, the Soviet Union, Czechoslovakia, and Yugoslavia dissolved the former having many states seceded and the latter violently over several years, into successor states, with many rife with ethnic nationalism.
#  - Entity: the Soviet Union (GPE)
#  - Entity: Czechoslovakia (GPE)
#  - Entity: Yugoslavia (GPE)
#  - Entity: several years (DATE)
#
# Sentence: Meanwhile, East Germany and West Germany were reunified in .
#  - Entity: East Germany (GPE)
#  - Entity: West Germany (GPE)
#
# Sentence: The Tiananmen Square protests of , culminating in the deaths of hundreds of civilian protesters and thousands of wounded, were a series of demonstrations in and near Tiananmen Square in Beijing, China.
#  - Entity: Tiananmen Square (FAC)
#  - Entity: hundreds (CARDINAL)
#  - Entity: thousands (CARDINAL)
#  - Entity: Tiananmen Square (FAC)
#  - Entity: Beijing (GPE)
#  - Entity: China (GPE)
#
# Sentence: Led mainly by students and intellectuals, the protests occurred in a year that saw the collapse of a number of communist governments around the world.
#  - Entity: a year (DATE)
#
# Sentence: Soviet coup attempt, a failed attempt by hardliners of the Communist Party of the Soviet Union CPSU to forcibly seize control of the country from Mikhail Gorbachev, who was Soviet President and General Secretary of the CPSU at the time.
#  - Entity: Soviet (NORP)
#  - Entity: the Communist Party (ORG)
#  - Entity: the Soviet Union (GPE)
#  - Entity: Mikhail Gorbachev (PERSON)
#  - Entity: Soviet (NORP)
#
# Sentence: Bosnian War, international armed conflict that took place in Bosnia and Herzegovina between and .
#  - Entity: Bosnian War (EVENT)
#  - Entity: Bosnia and Herzegovina (GPE)
#
# Sentence: The Rwandan genocide, over a span of around days, members of the Tutsi ethnic group, as well as some moderate Hutu and Twa, were systematically killed by Hutu militias.
#  - Entity: Rwandan (NORP)
#  - Entity: a span of around days (DATE)
#  - Entity: Tutsi (GPE)
#  - Entity: Hutu (PERSON)
#  - Entity: Hutu (PERSON)
#
# Sentence: European integration began in earnest in the 1950s, and eventually led to the European Union, a political and economic union that comprised countries at the end of the 20th century.
#  - Entity: European (NORP)
#  - Entity: the 1950s (DATE)
#  - Entity: the European Union (ORG)
#  - Entity: the end of the 20th century (DATE)
#
# Sentence: As the century began, Paris was the artistic capital of the world, where both French and foreign writers, composers and visual artists gathered.
#  - Entity: the century (DATE)
#  - Entity: Paris (GPE)
#  - Entity: French (NORP)
#
# Sentence: By the middle of the century New York City had become the artistic capital of the world.
#  - Entity: the middle of the century (DATE)
#  - Entity: New York City (GPE)
#
# Sentence: Theater, films, music and the media had a major influence on fashion and trends in all aspects of life.
#  - Entity: Theater (ORG)
#
# Sentence: As many films and much music originate from the United States, American culture spread rapidly over the world.
#  - Entity: the United States (GPE)
#  - Entity: American (NORP)
#
# Sentence: saw the coronation of Queen Elizabeth II, an iconic figure of the century.
#  - Entity: the century (DATE)
#
# Sentence: Visual culture became more dominant not only in films but in comics and television as well.
#
# Sentence: During the century a new skilled understanding of narrativist imagery was developed.
#  - Entity: the century (DATE)
#
# Sentence: Computer games and internet surfing became new and popular form of entertainment during the last years of the century.
#  - Entity: the last years of the century (DATE)
#
# Sentence: In literature, science fiction, fantasy with welldeveloped fictional worlds, rich in detail, and alternative history fiction gained popularity.
#
# Sentence: Detective fiction gained popularity in the interwar period.
#
# Sentence: In the United States in Grove Press published Tropic of Cancer a novel by Henry Miller redefining pornography and censorship in publishing in America.
#  - Entity: the United States (GPE)
#  - Entity: Grove Press (ORG)
#  - Entity: Henry Miller (PERSON)
#  - Entity: America (GPE)
#
# Sentence: Igor Stravinsky revolutionized classical composition.
#
# Sentence: In the 1920s, Arnold Schoenberg developed the twelvetone technique, which became widely influential on 20thcentury composers.
#  - Entity: the 1920s (DATE)
#  - Entity: Arnold Schoenberg (PERSON)
#  - Entity: 20thcentury (CARDINAL)
#
# Sentence: In classical music, composition branched out into many completely new domains, including dodecaphony, aleatoric chance music, and minimalism.
#
# Sentence: Tango was created in Argentina and became extremely popular in the rest of the Americas and Europe.
#  - Entity: Tango (PERSON)
#  - Entity: Argentina (GPE)
#  - Entity: Americas (LOC)
#  - Entity: Europe (LOC)
#
# Sentence: Blues and jazz music became popularized during the 1910s, 1920s and 1930s in the United States.
#  - Entity: the 1910s (DATE)
#  - Entity: 1920s (DATE)
#  - Entity: 1930s (DATE)
#  - Entity: the United States (GPE)
#
# Sentence: Bebop develops as a form of jazz in the 1940s.
#  - Entity: the 1940s (DATE)
#
# Sentence: Country music develops in the 1920s and 1930s in the United States.
#  - Entity: the 1920s (DATE)
#  - Entity: 1930s (DATE)
#  - Entity: the United States (GPE)
#
# Sentence: Blues and country went on to influence rock and roll in the 1950s, which along with folk music, increased in popularity with the British Invasion of the midtolate 1960s.
#  - Entity: the 1950s (DATE)
#  - Entity: the British Invasion (EVENT)
#  - Entity: 1960s (DATE)
#
# Sentence: Rock soon branched into many different genres, including folk rock, heavy metal, punk rock, and alternative rock and became the dominant genre of popular music.
#
# Sentence: This was challenged with the rise of hip hop in the 1980s and 1990s.
#  - Entity: the 1980s and (DATE)
#  - Entity: 1990s (DATE)
#
# Sentence: Other genres such as house, techno, reggae, and soul all developed during the latter half of the century and went through various periods of popularity.
#  - Entity: the latter half of the century (DATE)
#
# Sentence: Synthesizers began to be employed widely in music and crossed over into the mainstream with new wave music in the 1980s.
#  - Entity: the 1980s (DATE)
#
# Sentence: Electronic instruments have been widely deployed in all manners of popular music and has led to the development of such genres as house, synthpop, electronic dance music, and industrial.
#
# Sentence: Julie Andrews, Harry Belafonte, Humphrey Bogart, Marlon Brando, James Cagney, Charlie Chaplin, Sean Connery, Tom Cruise, James Dean, Robert De Niro, Harrison Ford, Clark Gable, Cary Grant, Audrey Hepburn, Katharine Hepburn, Bruce Lee, Marilyn Monroe, Paul Newman, Jack Nicholson, Al Pacino, Sidney Poitier, Meryl Streep, Elizabeth Taylor, James Stewart, Jane Fonda and John Wayne are among the most popular Hollywood stars of the 20th century.
#  - Entity: Julie Andrews (PERSON)
#  - Entity: Harry Belafonte (PERSON)
#  - Entity: Humphrey Bogart (PERSON)
#  - Entity: Marlon Brando (PERSON)
#  - Entity: James Cagney (PERSON)
#  - Entity: Charlie Chaplin (PERSON)
#  - Entity: Sean Connery (PERSON)
#  - Entity: Tom Cruise (PERSON)
#  - Entity: James Dean (PERSON)
#  - Entity: Robert De Niro (PERSON)
#  - Entity: Harrison Ford (PERSON)
#  - Entity: Clark Gable (PERSON)
#  - Entity: Cary Grant (PERSON)
#  - Entity: Audrey Hepburn (PERSON)
#  - Entity: Katharine Hepburn (PERSON)
#  - Entity: Bruce Lee (PERSON)
#  - Entity: Marilyn Monroe (PERSON)
#  - Entity: Paul Newman (PERSON)
#  - Entity: Jack Nicholson (PERSON)
#  - Entity: Al Pacino (PERSON)
#  - Entity: Sidney Poitier (PERSON)
#  - Entity: Meryl Streep (PERSON)
#  - Entity: Elizabeth Taylor (PERSON)
#  - Entity: James Stewart (PERSON)
#  - Entity: Jane Fonda (PERSON)
#  - Entity: John Wayne (PERSON)
#  - Entity: Hollywood (GPE)
#  - Entity: the 20th century (DATE)
#
# Sentence: Madhubala, JeanPaul Belmondo, Karel Roden, Sean Connery, Marcello Mastroianni, Salah Zulfikar, Marlene Dietrich, Brigitte Bardot, Omar Sharif, Catherine Deneuve, Alain Delon, Soad Hosny, Fernanda Montenegro, Sophie Marceau, Fatima Rushdi, Amitabh Bachchan, Jean Gabin, Toshiro Mifune, Shoukry Sarhan, Lars Mikkelsen, Sophia Loren, Youssef Wahbi, Claudia Cardinale, Klaus Kinski, Grard Depardieu, Max von Sydow, Faten Hamama, Rutger Hauer and Toni Servillo are among the most popular movie stars of the 20th century.
#  - Entity: Madhubala (PERSON)
#  - Entity: JeanPaul Belmondo (PERSON)
#  - Entity: Karel Roden (PERSON)
#  - Entity: Sean Connery (PERSON)
#  - Entity: Marcello Mastroianni (PERSON)
#  - Entity: Salah Zulfikar (PERSON)
#  - Entity: Marlene Dietrich (PERSON)
#  - Entity: Brigitte Bardot (PERSON)
#  - Entity: Omar Sharif (PERSON)
#  - Entity: Catherine Deneuve (PERSON)
#  - Entity: Soad Hosny (PERSON)
#  - Entity: Fernanda Montenegro (PERSON)
#  - Entity: Sophie Marceau (ORG)
#  - Entity: Fatima Rushdi (PERSON)
#  - Entity: Amitabh Bachchan (PERSON)
#  - Entity: Jean Gabin (PERSON)
#  - Entity: Toshiro Mifune (PERSON)
#  - Entity: Shoukry Sarhan (PERSON)
#  - Entity: Lars Mikkelsen (PERSON)
#  - Entity: Sophia Loren (PERSON)
#  - Entity: Youssef Wahbi (PERSON)
#  - Entity: Claudia Cardinale (ORG)
#  - Entity: Klaus Kinski (PERSON)
#  - Entity: Grard Depardieu (PERSON)
#  - Entity: Max von Sydow (PERSON)
#  - Entity: Faten Hamama (PERSON)
#  - Entity: Rutger Hauer (PERSON)
#  - Entity: Toni Servillo (PERSON)
#  - Entity: the 20th century (DATE)
#
# Sentence: Sergei Eisenstein, D. W. Griffith, Cecil B. DeMille, Frank Capra, Howard Hawks, John Ford, Orson Welles, Martin Scorsese, John Huston, Alfred Hitchcock, Akira Kurosawa, Spike Lee, Ingmar Bergman, Federico Fellini, Walt Disney, Stanley Kubrick, Steven Spielberg, Sergey Parajanov, Ridley Scott, Woody Allen, Quentin Tarantino, James Cameron, William Friedkin, Ezz ElDine Zulficar and George Lucas are among the most important and popular filmmakers of the 20th century.
#  - Entity: Sergei Eisenstein (PERSON)
#  - Entity: D. W. Griffith (PERSON)
#  - Entity: Cecil B. DeMille (PERSON)
#  - Entity: Frank Capra (PERSON)
#  - Entity: Howard Hawks (PERSON)
#  - Entity: John Ford (PERSON)
#  - Entity: Orson Welles (PERSON)
#  - Entity: Martin Scorsese (PERSON)
#  - Entity: John Huston (PERSON)
#  - Entity: Alfred Hitchcock (PERSON)
#  - Entity: Akira Kurosawa (PERSON)
#  - Entity: Spike Lee (PERSON)
#  - Entity: Ingmar Bergman (PERSON)
#  - Entity: Federico Fellini (PERSON)
#  - Entity: Walt Disney (ORG)
#  - Entity: Stanley Kubrick (PERSON)
#  - Entity: Steven Spielberg (PERSON)
#  - Entity: Sergey Parajanov (PERSON)
#  - Entity: Ridley Scott (PERSON)
#  - Entity: Woody Allen (PERSON)
#  - Entity: Quentin Tarantino (PERSON)
#  - Entity: James Cameron (PERSON)
#  - Entity: William Friedkin (PERSON)
#  - Entity: ElDine Zulficar (PERSON)
#  - Entity: George Lucas (PERSON)
#  - Entity: the 20th century (DATE)
#
# Sentence: In theater, sometimes referred to as Broadway in New York City, playwrights such as Eugene ONeill, Samuel Beckett, Edward Albee, Arthur Miller and Tennessee Williams introduced innovative language and ideas to the idiom.
#  - Entity: Broadway (FAC)
#  - Entity: New York City (GPE)
#  - Entity: Eugene ONeill (PERSON)
#  - Entity: Samuel Beckett (PERSON)
#  - Entity: Edward Albee (PERSON)
#  - Entity: Arthur Miller (PERSON)
#  - Entity: Tennessee Williams (PERSON)
#
# Sentence: In musical theater, figures such as Rodgers and Hammerstein, Lerner and Loewe, Mohammed Karim, and Irving Berlin had an enormous impact on both film and the culture in general.
#  - Entity: Rodgers (PERSON)
#  - Entity: Hammerstein (PERSON)
#  - Entity: Lerner (PERSON)
#  - Entity: Loewe (PERSON)
#  - Entity: Mohammed Karim (PERSON)
#  - Entity: Irving Berlin (PERSON)
#
# Sentence: Modern dance is born in America as a rebellion against centuriesold European ballet.
#  - Entity: America (GPE)
#  - Entity: European (NORP)
#
# Sentence: Dancers and choreographers Alvin Ailey, Isadora Duncan, Vaslav Nijinsky, Ruth St. Denis, Mahmoud Reda, Martha Graham, Jos Limn, Doris Humphrey, Merce Cunningham, and Paul Taylor redefined movement, struggling to bring it back to its natural roots and along with Jazz, created a solely American art form.
#  - Entity: Alvin Ailey (PERSON)
#  - Entity: Isadora Duncan (PERSON)
#  - Entity: Vaslav Nijinsky (PERSON)
#  - Entity: Ruth St. Denis (PERSON)
#  - Entity: Mahmoud Reda (PERSON)
#  - Entity: Martha Graham (PERSON)
#  - Entity: Jos Limn (PERSON)
#  - Entity: Doris Humphrey (PERSON)
#  - Entity: Merce Cunningham (PERSON)
#  - Entity: Paul Taylor (PERSON)
#  - Entity: American (NORP)
#
# Sentence: Alvin Ailey is credited with popularizing modern dance and revolutionizing AfricanAmerican participation in 20thcentury concert dance.
#  - Entity: Alvin Ailey (PERSON)
#  - Entity: AfricanAmerican (ORG)
#  - Entity: 20thcentury (CARDINAL)
#
# Sentence: His company gained the nickname Cultural Ambassador to the World because of its extensive international touring.
#  - Entity: Cultural (ORG)
#
# Sentence: Aileys choreographic masterpiece Revelations is believed to be the best known and most often seen modern dance performance.
#  - Entity: Aileys (PERSON)
#
# Sentence: While already conceptualized in the 1940s50s, video games only emerged as an industry during the 1970s, and then exploded into social and cultural phenomena in the late 1970s and early 1980s with the golden age of arcade video games, with notable releases such as Taitos Space Invaders, Atari, Inc.s Asteroids, Nintendos Donkey Kong, Namcos PacMan and Galaga, Konamis Frogger, Capcoms and Segas Zaxxon, the worldwide success of Nintendos Super Mario Bros. and the release in the 1990s of Sony PlayStation console, the first one to break the record of million units sold, with Gran Turismo being the systems best selling video game.
#  - Entity: the 1940s50s (DATE)
#  - Entity: the 1970s (DATE)
#  - Entity: the late 1970s (DATE)
#  - Entity: early 1980s (DATE)
#  - Entity: Taitos Space Invaders (ORG)
#  - Entity: Atari (ORG)
#  - Entity: Namcos PacMan (ORG)
#  - Entity: Konamis Frogger (PERSON)
#  - Entity: Capcoms (ORG)
#  - Entity: Segas Zaxxon (PERSON)
#  - Entity: Nintendos Super Mario Bros. (ORG)
#  - Entity: the 1990s (DATE)
#  - Entity: Sony (ORG)
#  - Entity: PlayStation (PRODUCT)
#  - Entity: first (ORDINAL)
#  - Entity: million (CARDINAL)
#  - Entity: Gran Turismo (ORG)
#
# Sentence: Video game design becomes a discipline.
#
# Sentence: Some game designers in this century stand out for their work, such as Shigeru Miyamoto, Hideo Kojima, Sid Meier and Will Wright.
#  - Entity: this century (DATE)
#  - Entity: Shigeru Miyamoto (PERSON)
#  - Entity: Hideo Kojima (PERSON)
#  - Entity: Sid Meier (PERSON)
#  - Entity: Will Wright (PERSON)
#
# Sentence: The art world experienced the development of new styles and explorations such as fauvism, expressionism, Dadaism, cubism, de stijl, surrealism, abstract expressionism, color field, pop art, minimal art, lyrical abstraction, and conceptual art.
#  - Entity: Dadaism (ORG)
#
# Sentence: The modern art movement revolutionized art and culture and set the stage for both Modernism and its counterpart postmodern art as well as other contemporary art practices.
#
# Sentence: Art Nouveau began as a form of architecture and design but fell out of fashion after World War I.
#  - Entity: Art Nouveau (PERSON)
#  - Entity: World War I. (EVENT)
#
# Sentence: The style was dynamic and inventive but unsuited to the depression of the Great War.
#  - Entity: the Great War (EVENT)
#
# Sentence: In Europe, modern architecture departed from the decorated styles of the Victorian era.
#  - Entity: Europe (LOC)
#  - Entity: Victorian (NORP)
#
# Sentence: Streamlined forms inspired by machines became commonplace, enabled by developments in building materials and technologies.
#
# Sentence: Before World War II, many European architects moved to the United States, where modern architecture continued to develop.
#  - Entity: Before World War II (EVENT)
#  - Entity: European (NORP)
#  - Entity: the United States (GPE)
#
# Sentence: The automobile increased the mobility of people in the Western countries in the earlytomidcentury, and in many other places by the end of the 20th century.
#  - Entity: Western (NORP)
#  - Entity: the end of the 20th century (DATE)
#
# Sentence: City design throughout most of the West became focused on transport via car.
#  - Entity: West (LOC)
#
# Sentence: The popularity of sport increased considerablyboth as an activity for all and as entertainment, particularly on television.
#
# Sentence: The modern Olympic Games, first held in , grew to include tens of thousands of athletes in dozens of sports.
#  - Entity: Olympic Games (EVENT)
#  - Entity: first (ORDINAL)
#  - Entity: tens of thousands (CARDINAL)
#  - Entity: dozens (CARDINAL)
#
# Sentence: The FIFA World Cup was first held in and was held every four years after World War II.
#  - Entity: World Cup (EVENT)
#  - Entity: first (ORDINAL)
#  - Entity: every four years (DATE)
#  - Entity: World War II (EVENT)
#
# Sentence: American League Baseball was formed in and in , both National and American agreed to play in the first World Series with over , in attendance.
#  - Entity: American League Baseball (ORG)
#  - Entity: National (ORG)
#  - Entity: American (NORP)
#  - Entity: first (ORDINAL)
#  - Entity: World Series (EVENT)
#
# Sentence: Boxing, also known as Prize Fighting became popular over this decade although bareknuckle fighting was still popular.
#  - Entity: Prize Fighting (PERSON)
#  - Entity: this decade (DATE)
#
# Sentence: New areas of physics, like special relativity, general relativity, and quantum mechanics, were developed during the first half of the century.
#  - Entity: the first half of the century (DATE)
#
# Sentence: In the process, the internal structure of atoms came to be clearly understood, followed by the discovery of elementary particles.
#
# Sentence: It was found that all the known forces can be traced to only four fundamental interactions.
#  - Entity: only four (CARDINAL)
#
# Sentence: It was discovered further that two forces, electromagnetism and weak interaction, can be merged in the electroweak interaction, leaving only three different fundamental interactions.
#  - Entity: two (CARDINAL)
#  - Entity: only three (CARDINAL)
#
# Sentence: Discovery of nuclear reactions, in particular nuclear fusion, finally revealed the source of solar energy.
#
# Sentence: Radiocarbon dating was invented, and became a powerful technique for determining the age of prehistoric animals and plants as well as historical objects.
#
# Sentence: A much better understanding of the evolution of the universe was achieved, its age about .
#
# Sentence: billion years was determined, and the Big Bang theory on its origin was proposed and generally accepted.
#  - Entity: the Big Bang (ORG)
#
# Sentence: The age of the Solar System, including Earth, was determined, and it turned out to be much older than believed earlier more than billion years, rather than the million years suggested by Lord Kelvin in .
#  - Entity: Earth (LOC)
#  - Entity: more than billion years (MONEY)
#  - Entity: the million years (DATE)
#  - Entity: Kelvin (PERSON)
#
# Sentence: The planets of the Solar System and their moons were closely observed via numerous space probes.
#  - Entity: the Solar System (ORG)
#
# Sentence: Pluto was discovered in on the edge of the Solar System, although in the early 21st century, it was reclassified as a dwarf planet instead of a planet proper, leaving eight planets.
#  - Entity: the Solar System (ORG)
#  - Entity: the early 21st century (DATE)
#  - Entity: eight (CARDINAL)
#
# Sentence: No trace of life was discovered on any of the other planets orbiting the Sun or elsewhere in the universe, although it remained undetermined whether some forms of primitive life might exist, or might have existed, somewhere in the Solar System.
#  - Entity: Sun (ORG)
#  - Entity: the Solar System (ORG)
#
# Sentence: Extrasolar planets were observed for the first time.
#  - Entity: first (ORDINAL)
#
# Sentence: Norman Borlaug fathered the Green Revolution, the set of research technology transfer initiatives occurring between and the late 1960s that increased agricultural production in parts of the world, beginning most markedly in the late 1960s, and is often credited with saving over a billion people worldwide from starvation.
#  - Entity: Norman Borlaug (PERSON)
#  - Entity: the Green Revolution (LOC)
#  - Entity: the late 1960s (DATE)
#  - Entity: the late 1960s (DATE)
#
# Sentence: Genetics was unanimously accepted and significantly developed.
#  - Entity: Genetics (ORG)
#
# Sentence: The structure of DNA was determined in by James Watson, Francis Crick, Rosalind Franklin48 and Maurice Wilkins, following by developing techniques which allow to read DNA sequences and culminating in starting the Human Genome Project not finished in the 20th century and cloning the first mammal in .
#  - Entity: James Watson (PERSON)
#  - Entity: Francis Crick (PERSON)
#  - Entity: Rosalind Franklin48 (PERSON)
#  - Entity: Maurice Wilkins (PERSON)
#  - Entity: the Human Genome Project (ORG)
#  - Entity: the 20th century (DATE)
#  - Entity: first (ORDINAL)
#
# Sentence: The role of sexual reproduction in evolution was understood, and bacterial conjugation was discovered.
#
# Sentence: The convergence of various sciences for the formulation of the modern evolutionary synthesis produced between and , providing a widely accepted account of evolution.
#
# Sentence: Placebocontrolled, randomized, blinded clinical trials became a powerful tool for testing new medicines.
#
# Sentence: Antibiotics drastically reduced mortality from bacterial diseases.
#
# Sentence: A vaccine was developed for polio, ending a worldwide epidemic.
#
# Sentence: Effective vaccines were also developed for a number of other serious infectious diseases, including influenza, diphtheria, pertussis whooping cough, tetanus, measles, mumps, rubella German measles, chickenpox, hepatitis A, and hepatitis B. Epidemiology and vaccination led to the eradication of the smallpox virus in humans.
#  - Entity: German (NORP)
#  - Entity: B. Epidemiology (ORG)
#
# Sentence: Xrays became a powerful diagnostic tool for a wide spectrum of diseases, from bone fractures to cancer.
#
# Sentence: In the 1960s, computerized tomography was invented.
#  - Entity: the 1960s (DATE)
#
# Sentence: Other important diagnostic tools developed were sonography and magnetic resonance imaging.
#
# Sentence: Development of vitamins virtually eliminated scurvy and other vitamindeficiency diseases from industrialized societies.
#
# Sentence: New psychiatric drugs were developed.
#
# Sentence: These include antipsychotics for treating hallucinations and delusions, and antidepressants for treating depression.
#
# Sentence: The role of tobacco smoking in the causation of cancer and other diseases was proven during the 1950s see British Doctors Study.
#  - Entity: the 1950s (DATE)
#  - Entity: British Doctors Study (ORG)
#
# Sentence: New methods for cancer treatment, including chemotherapy, radiation therapy, and immunotherapy, were developed.
#
# Sentence: As a result, cancer could often be cured or placed in remission.
#
# Sentence: The development of blood typing and blood banking made blood transfusion safe and widely available.
#
# Sentence: The invention and development of immunosuppressive drugs and tissue typing made organ and tissue transplantation a clinical reality.
#
# Sentence: New methods for heart surgery were developed, including pacemakers and artificial hearts.
#
# Sentence: Cocaine and heroin were widely illegalized after being found to be addictive and destructive.
#  - Entity: Cocaine (ORG)
#
# Sentence: Psychoactive drugs such as LSD and MDMA were discovered and subsequently prohibited in many countries.
#  - Entity: MDMA (ORG)
#
# Sentence: Prohibition of drugs caused a growth in the black market drug industry, and expanded enforcement led to a larger prison population in some countries.
#
# Sentence: Contraceptive drugs were developed, which reduced population growth rates in industrialized countries, as well as decreased the taboo of premarital sex throughout many western countries.
#
# Sentence: The development of medical insulin during the 1920s helped raise the life expectancy of diabetics to three times of what it had been earlier.
#  - Entity: the 1920s (DATE)
#  - Entity: three (CARDINAL)
#
# Sentence: Vaccines, hygiene and clean water improved health and decreased mortality rates, especially among infants and the young.
#  - Entity: Vaccines (ORG)
#
# Sentence: An influenza pandemic, Spanish Flu, killed anywhere from to million people between and .
#  - Entity: Spanish Flu (PERSON)
#  - Entity: million (CARDINAL)
#
# Sentence: A new viral disease, called the Human Immunodeficiency Virus, or HIV, arose in Africa and subsequently killed millions of people throughout the world.
#  - Entity: the Human Immunodeficiency Virus (ORG)
#  - Entity: Africa (LOC)
#  - Entity: millions (CARDINAL)
#
# Sentence: HIV leads to a syndrome called Acquired Immunodeficiency Syndrome, or AIDS.
#  - Entity: Acquired Immunodeficiency Syndrome (WORK_OF_ART)
#
# Sentence: Treatments for HIV remained inaccessible to many people living with AIDS and HIV in developing countries, and a cure has yet to be discovered.
#
# Sentence: Because of increased life spans, the prevalence of cancer, Alzheimers disease, Parkinsons disease, and other diseases of old age increased slightly.
#  - Entity: Alzheimers (NORP)
#
# Sentence: Changes in food production, along with sedentary lifestyles due to laborsaving devices and the increase in home entertainment, contributed to an epidemic of obesity, at first in the rich countries, but by the end of the 20th century spreading to the developing world.
#  - Entity: first (ORDINAL)
#  - Entity: the end of the 20th century (DATE)
#
# Sentence: Fossil fuels and nuclear power were the dominant forms of energy sources.
#
# Sentence: Widespread use of petroleum in industryboth as a chemical precursor to plastics and as a fuel for the automobile and airplaneled to the geopolitical importance of petroleum resources.
#
# Sentence: The Middle East, home to many of the worlds oil deposits, became a center of geopolitical and military tension throughout the latter half of the century.
#  - Entity: The Middle East (LOC)
#  - Entity: the latter half of the century (DATE)
#
# ...
#
# Sentence: Democide See various exclusions Charles Tilly .
#  - Entity: Charles Tilly (PERSON)
#
# Sentence: The politics of collective violence Cambridge University Press.
#  - Entity: Cambridge University Press (ORG)
#
# Sentence: ISBN .
#
# Sentence: Gary Rodger Weaver .
#  - Entity: Gary Rodger Weaver (PERSON)
#
# Sentence: Culture, Communication, and Conflict.
#
# Sentence: Simon Schuster.
#  - Entity: Simon Schuster (PERSON)
#
# Sentence: ISBN Suny , pp. , .
#  - Entity: ISBN Suny (PERSON)
#  - Entity: pp. (GPE)
#
# Sentence: Bozarslan, Duclert Kvorkian , p. .
#  - Entity: Bozarslan (PERSON)
#  - Entity: Duclert Kvorkian (PERSON)
#
# Sentence: Sabet, Amr G. E. .
#  - Entity: Amr G. E. (PERSON)
#
# Sentence: A History of the Modern Middle East, 4th ed.
#  - Entity: 4th (ORDINAL)
#
# Sentence: American Journal of Islam and Society. .
#  - Entity: American Journal of (ORG)
#  - Entity: Islam (ORG)
#  - Entity: Society (ORG)
#
# Sentence: doi10.35632ajis.v27i1.. ISSN .
#  - Entity: doi10.35632ajis.v27i1 (PERSON)
#  - Entity: ISSN (ORG)
#
# Sentence: McMahon, Henry Ali, Hussein Ibn , .
#  - Entity: McMahon (ORG)
#  - Entity: Henry Ali (PERSON)
#  - Entity: Hussein Ibn (PERSON)
#
# Sentence: British Diplomacy The HusseinMcMahon Letters, The World War I Reader, New York University Press, pp. , doi10.18574nyu9780814759332.., ISBN , retrieved The SykesPicot Agreement , The ArabIsraeli Conflict, Routledge, pp. , , doi10., ISBN , retrieved Osage are Richest People Greatest Per Capita Wealth in World Results From Oil Deal.
#  - Entity: British (NORP)
#  - Entity: The HusseinMcMahon Letters (ORG)
#  - Entity: The World War I Reader, New York University Press (EVENT)
#  - Entity: pp. (GPE)
#  - Entity: doi10.18574nyu9780814759332 (PERSON)
#  - Entity: The SykesPicot Agreement (WORK_OF_ART)
#  - Entity: The ArabIsraeli Conflict, Routledge (WORK_OF_ART)
#  - Entity: pp. (GPE)
#
# Sentence: The New York Times.
#  - Entity: The New York Times (ORG)
#
# Sentence: ISSN .
#  - Entity: ISSN (ORG)
#
# Sentence: Retrieved .
#
# Sentence: Brown, DeNeen L. October , .
#  - Entity: Brown (PERSON)
#  - Entity: DeNeen L. October (PERSON)
#
# Sentence: HBOs Watchmen depicts a deadly Tulsa race massacre that was all too real.
#  - Entity: Watchmen (PRODUCT)
#  - Entity: Tulsa (GPE)
#
# Sentence: Washington Post.
#  - Entity: Washington Post (ORG)
#
# Sentence: Retrieved July , .
#  - Entity: July (DATE)
#
# Sentence: White city police officer deputized members of the lynch mob and instructed them to get a gun and get a n, according to the Oklahoma Historical Society.
#  - Entity: White city (GPE)
#  - Entity: the Oklahoma Historical Society (ORG)
#
# Sentence: Tulsa race massacre of Commission, Facts, Books.
#  - Entity: Tulsa (GPE)
#  - Entity: Commission (ORG)
#  - Entity: Facts, Books (ORG)
#
# Sentence: Britannica.
#  - Entity: Britannica (PERSON)
#
# Sentence: Retrieved September , .
#  - Entity: September (DATE)
#
# Sentence: The Palestinian Nakba, The Politics of Denial, Pluto Press, pp. , doi10.2307j.ctt18dztmq., retrieved VS .
#  - Entity: The Palestinian Nakba (ORG)
#  - Entity: The Politics of Denial, Pluto Press (ORG)
#  - Entity: pp. (GPE)
#  - Entity: doi10.2307j.ctt18dztmq. (GPE)
#  - Entity: VS (PRODUCT)
#
# Sentence: About the Nakba.
#  - Entity: Nakba (PERSON)
#
# Sentence: Question of Palestine.
#
# Sentence: Retrieved .
#
# Sentence: How Palestinians were expelled from their homes, May , retrieved Geoffrey A. Hosking .
#  - Entity: Palestinians (NORP)
#  - Entity: May (PERSON)
#  - Entity: Geoffrey A. Hosking (PERSON)
#
# Sentence: Russia and the Russians a history.
#  - Entity: Russia (GPE)
#  - Entity: Russians (NORP)
#
# Sentence: Harvard University Press.
#  - Entity: Harvard University Press (ORG)
#
# Sentence: ISBN The Other Killing Machine.
#  - Entity: The Other Killing Machine (WORK_OF_ART)
#
# Sentence: May , Jump up to a b Chinas great famine years later.
#  - Entity: Jump (PERSON)
#  - Entity: Chinas (PERSON)
#  - Entity: years later (DATE)
#
# Sentence: British Medical Journal December Thee, Marek .
#  - Entity: British Medical Journal December Thee (ORG)
#
# Sentence: The Indochina Wars Great Power Involvement Escalation and Disengagement.
#  - Entity: The Indochina Wars Great Power Involvement Escalation and Disengagement (ORG)
#
# Sentence: Journal of Peace Research. .
#
# Sentence: Sage Publications .
#
# Sentence: doi10.. JSTOR .
#
# Sentence: S2CID .
#
# Sentence: You saw it here first Pittsburghs Nickelodeon introduced the moving picture theater to the masses in .
#  - Entity: first (ORDINAL)
#  - Entity: Pittsburghs Nickelodeon (ORG)
#
# Sentence: Pittsburgh PostGazette.
#  - Entity: Pittsburgh PostGazette (ORG)
#
# Sentence: June .
#  - Entity: June (DATE)
#
# Sentence: Retrieved February .
#  - Entity: February (DATE)
#
# Sentence: Jason Whittaker , The cyberspace handbook, Routledge, p. , ISBN Coates, James May , .
#  - Entity: Jason Whittaker (PERSON)
#  - Entity: Routledge (PERSON)
#  - Entity: James May (PERSON)
#
# Sentence: How Mario Conquered America.
#  - Entity: Mario Conquered America (PERSON)
#
# Sentence: Chicago Tribune.
#  - Entity: Chicago Tribune (ORG)
#
# Sentence: Archived from the original on November , .
#  - Entity: November (DATE)
#
# Sentence: Retrieved February , .
#  - Entity: February (DATE)
#
# Sentence: PlayStation Breaks Record as the Fastest Computer Entertainment Platform to Reach Cumulative Shipment of Million Units PDF Press release.
#  - Entity: PlayStation Breaks Record (PRODUCT)
#  - Entity: the Fastest Computer Entertainment Platform (ORG)
#  - Entity: Reach Cumulative Shipment of (ORG)
#  - Entity: PDF Press (ORG)
#
# Sentence: Sony Computer Entertainment.
#  - Entity: Sony Computer Entertainment (ORG)
#
# Sentence: November .
#  - Entity: November (DATE)
#
# Sentence: Archived from the original PDF on January .
#  - Entity: PDF (ORG)
#  - Entity: January (DATE)
#
# Sentence: Retrieved June .
#  - Entity: June (DATE)
#
# Sentence: Giordano, Ralph G. Fun And Games In The Twentieth Century America A Historical Guide to Leisure.
#  - Entity: Giordano (PERSON)
#  - Entity: Ralph G. Fun (PERSON)
#  - Entity: The Twentieth Century America A Historical Guide to (ORG)
#
# Sentence: GreenWood Press.
#  - Entity: GreenWood Press (PERSON)
#
# Sentence: ISBN .
#
# Sentence: Boyer, Carl B. A history of mathematics.
#  - Entity: Boyer (PERSON)
#  - Entity: Carl B. (PERSON)
#
# Sentence: Merzbach, Uta C., , Rogers D. Spotswood Collection.
#  - Entity: Uta C. (PERSON)
#  - Entity: Rogers D. Spotswood Collection (ORG)
#
# Sentence: 2nd rev. ed.. New York Wiley.
#  - Entity: 2nd (ORDINAL)
#  - Entity: ed.. (PERSON)
#  - Entity: New York Wiley (GPE)
#
# Sentence: ISBN .
#
# Sentence: OCLC .
#  - Entity: OCLC (ORG)
#
# Sentence: Devaney, Robert L.
#  - Entity: Devaney (PERSON)
#  - Entity: Robert L. (PERSON)
#
# Sentence: A first course in chaotic dynamical systems theory and experiment .
#  - Entity: first (ORDINAL)
#
# Sentence: printing.
#
# Sentence: ed.. Reading, Mass. u.a. AddisonWesley.
#  - Entity: ed.. Reading (PERSON)
#  - Entity: Mass. (GPE)
#  - Entity: AddisonWesley (ORG)
#
# Sentence: ISBN .
#
# Sentence: Kenneth Appel Wolfgang Haken July .
#  - Entity: Kenneth Appel (PERSON)
#  - Entity: Wolfgang Haken July (PERSON)
#
# Sentence: Every Planar Map is FourColorable.
#  - Entity: Planar Map (PERSON)
#  - Entity: FourColorable (ORG)
#
# Sentence: Bulletin of the American Mathematical Society.
#  - Entity: the American Mathematical Society (ORG)
#
# Sentence: Contemporary Mathematics.
#  - Entity: Contemporary Mathematics (ORG)
#
# Sentence: doi10.1090conm098. ISBN .
#  - Entity: doi10.1090conm098 (ORG)
#
# Sentence: S2CID .
#
# Sentence: Thomson, Sir William .
#  - Entity: Thomson (ORG)
#  - Entity: William (PERSON)
#
# Sentence: On the Age of the Suns Heat.
#
# Sentence: Macmillans Magazine. .
#  - Entity: Macmillans Magazine (ORG)
#
# Sentence: Jump up to a b c The Nobel Prize in Physiology or Medicine .
#  - Entity: Jump (PERSON)
#  - Entity: The Nobel Prize in Physiology or Medicine (WORK_OF_ART)
#
# Sentence: NobelPrize.org.
#
# Sentence: Nobel Media AB.
#  - Entity: Nobel Media AB (ORG)
#
# Sentence: Retrieved November , .
#  - Entity: November (DATE)
#
# Sentence: Jump up to a b c d James Watson, Francis Crick, Maurice Wilkins, and Rosalind Franklin.
#  - Entity: Jump (PERSON)
#  - Entity: James Watson (PERSON)
#  - Entity: Francis Crick (PERSON)
#  - Entity: Maurice Wilkins (PERSON)
#  - Entity: Rosalind Franklin (PERSON)
#
# Sentence: Science History Institute.
#  - Entity: Science History Institute (ORG)
#
# Sentence: June .
#  - Entity: June (DATE)
#
# Sentence: Archived from the original on March .
#  - Entity: March (DATE)
#
# Sentence: Retrieved March .
#  - Entity: March (DATE)
#
# Sentence: Engel, Pamela April , .
#  - Entity: Engel (PERSON)
#  - Entity: Pamela April (PERSON)
#
# Sentence: Watch How Quickly The War On Drugs Changed Americas Prison Population.
#
# Sentence: Business Insider.
#  - Entity: Business Insider (ORG)
#
# Sentence: Global Positioning System History.
#
# Sentence: Retrieved .
#
# Sentence: Jacobson, Molly .
#  - Entity: Jacobson (PERSON)
#  - Entity: Molly (PERSON)
#
# Sentence: Seventh Lambeth Conference, Resolutions by the Anglican Communion.
#  - Entity: Seventh (ORDINAL)
#  - Entity: Lambeth Conference (PERSON)
#  - Entity: Resolutions (PERSON)
#  - Entity: the Anglican Communion (ORG)
#
# Sentence: Embryo Project Encyclopedia.
#
# Sentence: Retrieved .
#
# Sentence: IPCC AR5 WG1 , Stocker, T.F. eds., Climate Change The Physical Science Basis.
#  - Entity: AR5 WG1 (DATE)
#  - Entity: Stocker (PERSON)
#  - Entity: T.F. (PERSON)
#
# Sentence: Working Group WG1 Contribution to the Intergovernmental Panel on Climate Change IPCC 5th Assessment Report AR5, Cambridge University Presscitation CS1 maint numeric names authors list link.
#  - Entity: Working Group WG1 Contribution (ORG)
#  - Entity: the Intergovernmental Panel on Climate Change IPCC 5th Assessment Report AR5 (ORG)
#  - Entity: Cambridge University Presscitation CS1 (ORG)
#
# Sentence: Climate Change Working Group website.
#  - Entity: Change Working Group (ORG)
#
# Sentence: IPCC TAR WG2 .
#
# Sentence: McCarthy, J. J. Canziani, O. F. Leary, N. A. Dokken, D. White, K. S. eds..
#  - Entity: McCarthy (PERSON)
#  - Entity: J. J. Canziani (PERSON)
#  - Entity: O. F. Leary (PERSON)
#  - Entity: N. A. Dokken (PERSON)
#  - Entity: D. White (PERSON)
#  - Entity: K. S. (PERSON)
#
# Sentence: Climate Change Impacts, Adaptation and Vulnerability.
#
# Sentence: Contribution of Working Group II to the Third Assessment Report of the Intergovernmental Panel on Climate Change.
#  - Entity: Working Group II (ORG)
#  - Entity: the Intergovernmental Panel on Climate Change (ORG)
#
# Sentence: Cambridge University Press.
#  - Entity: Cambridge University Press (ORG)
#
# Sentence: Archived from the original on May .
#  - Entity: May (DATE)
#
# Sentence: Retrieved December .cite book CS1 maint numeric names authors list link pb Bozarslan, Hamit in French Duclert, Vincent in French Kvorkian, Raymond H. Comprendre le gnocide des armniens1915 nos jours
#  - Entity: December (DATE)
#  - Entity: Bozarslan (ORG)
#  - Entity: French (NORP)
#  - Entity: Duclert (PERSON)
#  - Entity: Vincent (PERSON)
#  - Entity: French (NORP)
#  - Entity: Kvorkian (PERSON)
#  - Entity: Raymond H. Comprendre (PERSON)
#
# Sentence: Understanding the Armenian genocide to the present day in French.
#  - Entity: Armenian (NORP)
#  - Entity: the present day (DATE)
#  - Entity: French (LANGUAGE)
#
# Sentence: Tallandier fr.
#
# Sentence: ISBN .
#
# Sentence: Suny, Ronald Grigor .
#  - Entity: Suny (ORG)
#  - Entity: Ronald Grigor (PERSON)
#
# Sentence: They Can Live in the Desert but Nowhere Else A History of the Armenian Genocide.
#  - Entity: Can Live in the Desert (WORK_OF_ART)
#  - Entity: the Armenian Genocide (FAC)
#
# Sentence: Princeton University Press.
#  - Entity: Princeton University Press (ORG)
#
# Sentence: ISBN .
#
# Sentence: Brower, Daniel R. and Thomas Sanders.
#  - Entity: Daniel R. (PERSON)
#  - Entity: Thomas Sanders (PERSON)
#
# Sentence: The World in the Twentieth Century 7th Ed, CBS News.
#  - Entity: The World (ORG)
#  - Entity: the Twentieth Century 7th Ed (EVENT)
#  - Entity: CBS News (ORG)
#
# Sentence: People of the century.
#  - Entity: the century (DATE)
#
# Sentence: Simon and Schuster, .
#  - Entity: Simon (PERSON)
#  - Entity: Schuster (PERSON)
#
# Sentence: ISBN Grenville, J. A History of the World in the Twentieth Century .
#  - Entity: J. A History (PERSON)
#  - Entity: the Twentieth Century (EVENT)
#
# Sentence: online free Hallock, Stephanie A.
#  - Entity: Hallock (ORG)
#  - Entity: Stephanie A. (PERSON)
#
# Sentence: The World in the 20th Century A Thematic Approach Langer, William.
#  - Entity: Century A Thematic Approach Langer (ORG)
#  - Entity: William (PERSON)
#
# Sentence: An Encyclopedia of World History 5th ed. highly detailed outline of events online free Morris, Richard B. and Graham W. Irwin, eds.
#  - Entity: 5th (ORDINAL)
#  - Entity: Morris (PERSON)
#  - Entity: Richard B. (PERSON)
#  - Entity: Graham W. Irwin (PERSON)
#
# Sentence: Harper Encyclopedia of the Modern World A Concise Reference History from to the Present online Pindyck, Robert S.
#  - Entity: Harper Encyclopedia (PERSON)
#  - Entity: the Modern World A Concise Reference History (ORG)
#  - Entity: Pindyck (GPE)
#  - Entity: Robert S. (PERSON)
#
# Sentence: What we know and dont know about climate change, and implications for policy.
#
# Sentence: Environmental and Energy Policy and the Economy .
#
# Sentence: online
#
# Sentence: Pollard, Sidney, ed.
#  - Entity: Pollard (GPE)
#
# Sentence: Wealth and Poverty an Economic History of the 20th Century , pp global perspective online free Stearns, Peter, ed.
#  - Entity: the 20th Century (DATE)
#  - Entity: free Stearns (ORG)
#  - Entity: Peter (PERSON)
#  - Entity: ed (PERSON)
#
# Sentence: The Encyclopedia of World History UNESCO .
#  - Entity: UNESCO (ORG)
#
# Sentence: The Twentieth Century.
#  - Entity: The Twentieth Century (ORG)
#
# Sentence: History of Humanity.
#  - Entity: Humanity (NORP)
#
# Sentence: Vol. VII.
#
# Sentence: Routledge.
#
# Sentence: ISBN .
#
# Sentence: The 20th Century Research Project archived February Slouching Towards Utopia The Economic History of the Twentieth Century archived February Discovering Literature 20th century at the British Library Millennia Centuries
#  - Entity: The 20th Century Research Project (ORG)
#  - Entity: February (DATE)
#  - Entity: the Twentieth Century (ORG)
#  - Entity: February (DATE)
#  - Entity: 20th century (DATE)
#  - Entity: the British Library Millennia Centuries (ORG)
#
# Sentence: Decades Years Events Timeline Art Christianity Literature classical Philosophy Theatre State leaders Earthquakes Lunar eclipses Riots Solar eclipses Volcanic eruptions Category FAST United States2 France BnF data Czech Republic Latvia Israel KulturNav 20th century 2nd millennium
#  - Entity: Theatre State (ORG)
#  - Entity: Earthquakes Lunar (PERSON)
#  - Entity: Riots Solar (PERSON)
#  - Entity: Volcanic (ORG)
#  - Entity: United (ORG)
#  - Entity: France (GPE)
#  - Entity: BnF (ORG)
#  - Entity: Czech Republic (GPE)
#  - Entity: Latvia (GPE)
#  - Entity: Israel (GPE)
#  - Entity: 20th century 2nd millennium (DATE)
#
# Sentence: Late modern period 20thcentury overviews Webarchive template wayback links Articles with short description Short description is different from Wikidata All articles with unsourced statements Articles with unsourced statements from January Articles with unsourced statements from February CS1 maint numeric names authors list CS1 interwikilinked names CS1 Frenchlanguage sources fr Commons category link from Wikidata
#  - Entity: 20thcentury (CARDINAL)
#  - Entity: Articles (PERSON)
#  - Entity: Wikidata (ORG)
#  - Entity: Articles (PRODUCT)
#  - Entity: January Articles (DATE)
#  - Entity: February (DATE)
#  - Entity: Wikidata (ORG)
#
# Sentence: This page was last edited on February , at UTC.
#  - Entity: February (DATE)
#  - Entity: UTC (ORG)
#
# Sentence: Text is available under the Creative Commons AttributionShareAlike .
#  - Entity: the Creative Commons (ORG)
#
# Sentence: License additional terms may apply.
#
# Sentence: By using this site, you agree to the Terms of Use and Privacy Policy.
#  - Entity: the Terms of Use and Privacy Policy (ORG)
#
# Sentence: Wikipedia is a registered trademark of the Wikimedia Foundation, Inc., a nonprofit organization.
#  - Entity: Wikipedia (ORG)
#  - Entity: the Wikimedia Foundation, Inc. (ORG)
#
# Sentence: Privacy policy Disclaimers Contact Wikipedia Code of Conduct Developers Statistics Cookie statement Mobile view Edit preview settings
#  - Entity: Mobile (GPE)

# %%
# Example country list
country_list = ["United States", "Germany", "France", "India", "China", "United Kingdom", "Canada","Russia"]

# %%
# Extract country names
country_entities = [ent.text for ent in doc.ents if ent.label_ == "GPE" and ent.text in country_list]

# %%
print("\nFiltered Country Entities:")
print(country_entities)
# Out:
# Filtered Country Entities:
# ['China', 'Germany', 'France', 'China', 'France', 'China', 'India', 'China', 'China', 'Canada', 'Russia', 'France']

# %%
# Create DataFrame
df = pd.DataFrame({"Country": country_entities})

# %%
# Display first few rows
df.head()
# Out:
#    Country
# 0    China
# 1  Germany
# 2   France
# 3    China
# 4   France

# %%
df.to_csv("country_entities.csv", index=False)

# %%
print("DataFrame saved as 'country_entities.csv'.")
# Out:
# DataFrame saved as 'country_entities.csv'.
